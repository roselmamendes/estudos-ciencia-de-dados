# %% [markdown]
# Dados em: https://dadosabertos.capes.gov.br/dataset/2018-catalogo-de-teses-e-dissertacoes-da-capes/resource/004e1beb-a972-47ac-b935-cbd9ddd12758

# %%
import pandas as pd
teses_dissertacoes = pd.read_csv("br-capes-btd-2018-2019-09-09_2018.csv", delimiter=';', encoding='iso-8859-1')

# %%
teses_dissertacoes.shape
# Out:
# (88120, 57)

# %%
pd.set_option("display.max.columns", None)

# %%
teses_dissertacoes.head()
# Out:
#    AN_BASE    CD_PROGRAMA                          NM_PROGRAMA  \
# 0     2018  51001012012P2                CIÊNCIA DA COMPUTAÇÃO
# 1     2018  33092010017P0  CIDADES INTELIGENTES E SUSTENTÁVEIS
# 2     2018  33092010017P0  CIDADES INTELIGENTES E SUSTENTÁVEIS
# 3     2018  33092010017P0  CIDADES INTELIGENTES E SUSTENTÁVEIS
# 4     2018  31004016044P4                  ENGENHARIA MECÂNICA
#
#   SG_ENTIDADE_ENSINO                                 NM_ENTIDADE_ENSINO  \
# 0               UFMS  FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO D...
# 1            UNINOVE                         UNIVERSIDADE NOVE DE JULHO
# 2            UNINOVE                         UNIVERSIDADE NOVE DE JULHO
# 3            UNINOVE                         UNIVERSIDADE NOVE DE JULHO
# 4               UERJ           UNIVERSIDADE DO ESTADO DO RIO DE JANEIRO
#
#    ID_ADD_PRODUCAO_INTELECTUAL  ID_PRODUCAO_INTELECTUAL  \
# 0                     24769825                  6319285
# ...

# %%
import numpy as np
teses_dissertacoes.describe(include=np.object)
# Out:
#           CD_PROGRAMA NM_PROGRAMA SG_ENTIDADE_ENSINO  \
# count           88120       88120              88120
# unique           4151        1786                434
# top     31075010001P2    EDUCAÇÃO                USP
# freq              636        3926               4552
#
#                NM_ENTIDADE_ENSINO  \
# count                       88120
# unique                        435
# top     UNIVERSIDADE DE SÃO PAULO
# freq                         4552
#
#                                               NM_PRODUCAO NM_SUBTIPO_PRODUCAO  \
# count                                               88120               88120
# unique                                              88054                  27
# top     O ALUNO DO PROGRAMA DE MESTRADO DO IMPA TEM A ...         DISSERTAÇÃO
# freq                                                   13               64151
#
#        NM_AREA_CONCENTRACAO  \
# count                 88120
# unique                 3899
# top           NÃO INFORMADO
# ...

# %%
teses_dissertacoes['NM_GRANDE_AREA_CONHECIMENTO'].value_counts()
# Out:
# CIÊNCIAS HUMANAS               14064
# CIÊNCIAS DA SAÚDE              13794
# CIÊNCIAS SOCIAIS APLICADAS     12691
# MULTIDISCIPLINAR               11751
# ENGENHARIAS                     9471
# CIÊNCIAS AGRÁRIAS               8396
# CIÊNCIAS EXATAS E DA TERRA      7280
# LINGÜÍSTICA, LETRAS E ARTES     5346
# CIÊNCIAS BIOLÓGICAS             5327
# Name: NM_GRANDE_AREA_CONHECIMENTO, dtype: int64

# %%
teses_dissertacoes['NM_AREA_CONHECIMENTO'].value_counts()
# Out:
# INTERDISCIPLINAR       5751
# EDUCAÇÃO               5411
# MEDICINA               5166
# ADMINISTRAÇÃO          3931
# DIREITO                3521
#                        ...
# MUSEOLOGIA               49
# BIOFÍSICA                49
# ARQUEOLOGIA              44
# ENGENHARIA DE MINAS      42
# ASTRONOMIA               39
# Name: NM_AREA_CONHECIMENTO, Length: 80, dtype: int64
