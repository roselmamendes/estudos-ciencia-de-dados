# %% [markdown]
# # Discentes em Pós Graduação
#
# O objetivo é entender quais as produções na Pós Graduação Brasileira por raça e sexo, nas áreas de exatas.
#
# Dados sobre estudantes no Capes (Pós-Graduação): https://dadosabertos.capes.gov.br/dataset/2017-2020-discentes-da-pos-graduacao-stricto-sensu-do-brasil/resource/37fde9f4-bb94-4806-85d4-5d744f7f76ef
#
# Dados relevantes para análise:
#
# AN_BASE
#
# NM_REGIAO
#
# DS_FAIXA_ETARIA
#
# NM_RACA_COR
#
# TP_SEXO_DISCENTE
#
# SG_UF_PROGRAMA
#
# IN_NECESSIDADE_PESSOAL

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.0 MB 873 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 2.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 20.2 MB 128 kB/s eta 0:00:01     |███████████████████████▎        | 14.7 MB 936 kB/s eta 0:00:06
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
discentes = pd.read_csv("br-capes-colsucup-discentes-2018-2019-10-01.csv", delimiter=';', encoding='iso-8859-1')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
discentes.head()
# Out:
#    AN_BASE NM_GRANDE_AREA_CONHECIMENTO  CD_AREA_AVALIACAO  \
# 0     2018  CIÊNCIAS SOCIAIS APLICADAS                 27
# 1     2018  CIÊNCIAS SOCIAIS APLICADAS                 27
# 2     2018  CIÊNCIAS SOCIAIS APLICADAS                 27
# 3     2018  CIÊNCIAS SOCIAIS APLICADAS                 27
# 4     2018  CIÊNCIAS SOCIAIS APLICADAS                 27
#
#                                    NM_AREA_AVALIACAO SG_ENTIDADE_ENSINO  \
# 0  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...               FURG
# 1  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...               UFCG
# 2  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...               FURG
# 3  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...               UNIR
# 4  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...               UFMS
#
#                                   NM_ENTIDADE_ENSINO CS_STATUS_JURIDICO  \
# 0                 UNIVERSIDADE FEDERAL DO RIO GRANDE            FEDERAL
# ...

# %%
len(discentes)
# Out:
# 390421

# %%
discentes.describe()
# Out:
#         AN_BASE  CD_AREA_AVALIACAO     ID_PESSOA  QT_MES_TITULACAO  \
# count  390421.0      390421.000000  3.904210e+05     390421.000000
# mean     2018.0          26.017368  1.765976e+06          7.337805
# std         0.0          14.582318  1.021440e+06         14.797125
# min      2018.0           1.000000  9.500000e+01          0.000000
# 25%      2018.0          13.000000  8.062660e+05          0.000000
# 50%      2018.0          26.000000  2.002919e+06          0.000000
# 75%      2018.0          40.000000  2.658261e+06          0.000000
# max      2018.0          50.000000  3.408068e+06        185.000000
#
#        ID_ADD_FOTO_PROGRAMA  ID_ADD_FOTO_PROGRAMA_IES
# count         390421.000000             390421.000000
# mean           74218.917064             138484.298386
# std             1601.925491               1859.952257
# min            70784.000000             134658.000000
# 25%            72916.000000             136971.000000
# ...

# %%
discentes.shape
# Out:
# (390421, 35)

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %%
discentes.tail()
# Out:
#         AN_BASE  NM_GRANDE_AREA_CONHECIMENTO  CD_AREA_AVALIACAO  \
# 390416     2018  LINGÜÍSTICA, LETRAS E ARTES                 41
# 390417     2018  LINGÜÍSTICA, LETRAS E ARTES                 41
# 390418     2018  LINGÜÍSTICA, LETRAS E ARTES                 41
# 390419     2018  LINGÜÍSTICA, LETRAS E ARTES                 41
# 390420     2018             MULTIDISCIPLINAR                 49
#
#                NM_AREA_AVALIACAO SG_ENTIDADE_ENSINO  \
# 390416  LINGUÍSTICA E LITERATURA             UNEMAT
# 390417  LINGUÍSTICA E LITERATURA             UNEMAT
# 390418  LINGUÍSTICA E LITERATURA             UNEMAT
# 390419  LINGUÍSTICA E LITERATURA             UNEMAT
# 390420       CIÊNCIAS AMBIENTAIS               UNIC
#
#                            NM_ENTIDADE_ENSINO CS_STATUS_JURIDICO  \
# 390416  UNIVERSIDADE DO ESTADO DE MATO GROSSO           ESTADUAL
# 390417  UNIVERSIDADE DO ESTADO DE MATO GROSSO           ESTADUAL
# ...

# %%
import numpy as np
discentes.describe(include=np.object)
# Out:
#        NM_GRANDE_AREA_CONHECIMENTO NM_AREA_AVALIACAO SG_ENTIDADE_ENSINO  \
# count                       390421            390421             390421
# unique                           9                49                474
# top               CIÊNCIAS HUMANAS  INTERDISCIPLINAR                USP
# freq                         62676             25120              21376
#
#                NM_ENTIDADE_ENSINO CS_STATUS_JURIDICO  \
# count                      390421             390421
# unique                        475                  4
# top     UNIVERSIDADE DE SÃO PAULO            FEDERAL
# freq                        21376             229090
#
#        DS_DEPENDENCIA_ADMINISTRATIVA NM_MODALIDADE_PROGRAMA  \
# count                         390421                 390421
# unique                             2                      2
# top                          PÚBLICA              ACADÊMICO
# freq                          329513                 332038
#
# ...

# %%
discentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390421 entries, 0 to 390420
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   AN_BASE                         390421 non-null  int64
#  1   NM_GRANDE_AREA_CONHECIMENTO     390421 non-null  object
#  2   CD_AREA_AVALIACAO               390421 non-null  int64
#  3   NM_AREA_AVALIACAO               390421 non-null  object
#  4   SG_ENTIDADE_ENSINO              390421 non-null  object
#  5   NM_ENTIDADE_ENSINO              390421 non-null  object
#  6   CS_STATUS_JURIDICO              390421 non-null  object
#  7   DS_DEPENDENCIA_ADMINISTRATIVA   390421 non-null  object
#  8   NM_MODALIDADE_PROGRAMA          390421 non-null  object
#  9   NM_GRAU_PROGRAMA                390421 non-null  object
#  10  CD_PROGRAMA_IES                 390421 non-null  object
#  11  NM_PROGRAMA_IES                 390421 non-null  object
# ...
